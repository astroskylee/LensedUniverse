# %% [markdown]
# # Inspect MST error sources (why NaNs appear)
#
# This notebook inspects `static_datavectors_seed6.json` and the processed NPZ to explain
# where NaNs in `mst_err` come from.
#
# Key idea:
# - If a block lacks `sigma_v_measured`, MST is missing for that block.
# - For blocks with MST, NaNs can come from non-finite values in sigma_v_measured.

# %%
import json
import numpy as np
from pathlib import Path

json_path = Path('../Temp_data/static_datavectors_seed6.json')
npz_path = Path('/users/tianli/Temp_data/quasar_datavectors_seed6_processed.npz')

with json_path.open('r') as f:
    data = json.load(f)

print('Blocks:', len(data))

# %%
# ---------------------------
# Which blocks have MST inputs?
# ---------------------------
has_mst = np.array([('sigma_v_measured' in d) for d in data])
missing_blocks = np.where(~has_mst)[0]
print('Blocks without MST inputs:', missing_blocks.tolist())

# %%
# ---------------------------
# Per-block sizes and expected NaN counts in MST
# ---------------------------
rows = []
for b, d in enumerate(data):
    z_lens = np.asarray(d['z_lens'])
    td = np.asarray(d['td_measured'])
    n_lens = z_lens.shape[0]
    n_td = td.shape[2]
    n_obs = n_lens * n_td
    rows.append((b, n_lens, n_td, n_obs, bool(has_mst[b])))

print('block  n_lens  n_td  n_obs  has_mst')
for r in rows:
    print(f'{r[0]:5d} {r[1]:7d} {r[2]:4d} {r[3]:6d} {str(r[4]):>7}')

# %%
# ---------------------------
# For MST blocks, inspect finite fractions
# ---------------------------
for b, d in enumerate(data):
    if not has_mst[b]:
        continue
    sig = np.asarray(d['sigma_v_measured'], dtype=float)
    sig = sig.mean(axis=2)
    sig_f = np.isfinite(sig).mean()
    print(f'block {b:02d}: sigma_v finite={sig_f:.4f}')

# %%
# ---------------------------
# Diagnose mst_err NaNs from sigma_v_measured
# ---------------------------
eps = 1e-12
for b in np.where(has_mst)[0]:
    d = data[int(b)]
    sig = np.asarray(d['sigma_v_measured'], dtype=float)
    sig = sig.mean(axis=2)

    sig_finite = np.isfinite(sig)
    n_nonfinite = sig_finite.size - sig_finite.sum()

    sig_mean = np.mean(sig, axis=1)
    sig_std = np.std(sig, axis=1, ddof=1)

    mean_bad = (~np.isfinite(sig_mean)) | (np.abs(sig_mean) < eps)
    std_bad = ~np.isfinite(sig_std)

    mst_err_block = sig_std / sig_mean
    mst_bad = ~np.isfinite(mst_err_block)

    bad_idx = np.where(mst_bad)[0]

    print(f'block {int(b):02d}: nonfinite sigma_v={int(n_nonfinite)}, mean_bad={int(mean_bad.sum())}, std_bad={int(std_bad.sum())}, mst_bad={int(mst_bad.sum())}')
    print('  first bad lens idx:', bad_idx[:10].tolist())

# %%
# ---------------------------
# Compare with processed NPZ (NaN counts)
# ---------------------------
dnpz = np.load(npz_path)
mst_err = dnpz['mst_err']
block_id = dnpz['block_id']
lens_id = dnpz['lens_id']

nan_mask = ~np.isfinite(mst_err)
print('Total MST NaN entries:', nan_mask.sum())

for b in np.unique(block_id):
    m = block_id == b
    n_nan = np.sum(nan_mask[m])
    n_tot = np.sum(m)
    if n_nan > 0:
        bad_lens = np.unique(lens_id[m & nan_mask])
        print(f'block {int(b):02d}: NaN {n_nan}/{n_tot}, bad_lens={bad_lens[:10].tolist()}')
